# %%
import warnings
warnings.simplefilter('ignore')
import sys
sys.path.insert(0, '../src/')
import numpy as np
import ukdata as data
from functions import *
import DataProvider 
import uk_dale_meter
import refitdata as refit
from matplotlib import pyplot as plt
import random
import timeit
import matplotlib as mpl
from ploting import *
import matplotlib.dates as dates
import seaborn as sns
# %matplotlib inline
latexify(fig_width=8)

# %%
#Load fride data
path = "/home/ibcn079/data/ukdale/"
appliance = 'fridge'
aggregate, iam = data.generate_clean_data(path, appliance,buildings=[1,2])
main, app = data.resample_data(main=aggregate, meter=iam)
inputs, targets = np.array(main['aggregate']).flatten(), np.array(app['fridge']).flatten()
# Out:
# /home/ibcn079/data/ukdale/house1/
# Reading house: 1
# /home/ibcn079/data/ukdale/house2/
# Reading house: 2
# size of aggregate: 2780373
# size of meters: 1687285

# %%
fridge = iam
aggregate, kettle = data.generate_clean_data(path, "kettle",buildings=[1,2])
# Out:
# /home/ibcn079/data/ukdale/house1/
# Reading house: 1
# /home/ibcn079/data/ukdale/house2/
# Reading house: 2
# size of aggregate: 2780373
# size of meters: 2094523

# %%
kettle
# Out:
#                        Time  kettle
# 0       2013-02-17 16:00:22       0
# 1       2013-02-17 16:00:25       0
# 2       2013-02-17 16:00:31       0
# 3       2013-02-17 16:00:37       0
# 4       2013-02-17 16:00:43       0
# 5       2013-02-17 16:00:49       0
# 6       2013-02-17 16:00:55       0
# 7       2013-02-17 16:01:01       0
# 8       2013-04-16 21:18:09       1
# 9       2013-04-16 21:18:15       0
# 10      2013-04-16 21:18:21       1
# 11      2013-04-16 21:18:27       1
# 12      2013-04-16 21:18:33       0
# 13      2013-04-16 21:18:39       0
# 14      2013-04-16 21:18:46       0
# 15      2013-04-16 21:18:52       0
# 16      2013-04-16 21:18:58       0
# 17      2013-04-16 21:19:04       0
# 18      2013-04-16 21:19:10       0
# 19      2013-04-16 21:19:16       0
# 20      2013-04-16 21:19:23       1
# 21      2013-04-16 21:19:29       1
# 22      2013-04-16 21:19:35       1
# 23      2013-04-16 21:19:41       1
# 24      2013-04-16 21:19:47       1
# ...

# %%
kettle['2013-05-20 21:28:39':'2013-05-21 21:28:39'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-bf6424c9b082> in <module>()
# ----> 1 kettle['2013-05-20 21:28:39':'2013-05-21 21:28:39'].plot()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2125
#    2126         # see if we can slice the rows
# -> 2127         indexer = convert_to_index_sliceable(self, key)
#    2128         if indexer is not None:
#    2129             return self._getitem_slice(indexer)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in convert_to_index_sliceable(obj, key)
#    1978     idx = obj.index
#    1979     if isinstance(key, slice):
# -> 1980         return idx._convert_slice_indexer(key, kind='getitem')
#    1981
#    1982     elif isinstance(key, compat.string_types):
#
# ...
